# %% [markdown]
# ## Why do we need Mask Detection?
# In these uncertain times, human civilization needs to quickly adapt to the threat at hand. While wearing mask is not the ultimate solution, it still reduces the rate of transmission of the virus. For us, to create such safe ecosystem, we need techniques like Mask Detection to ensure that the rate of transmission is controlled in highly crowded public spaces and other areas where risk of transmission is high.
#
# In this notebook, following process is adopted:
# * Step1: Extract the face data for training.
# * Step2: Train the classifier to classify faces into mask or non-mask labels.
# * Step3: Detect Faces in testing data using SSD Face Detector.
# * Step4: By using the trained classifier, classify the detected faces.
#
# ## Content
# 1. [Importing Libraries and Directories](#section-one)<br>
# 2. [What is SSD?](#section-two)<br>
# 3. [Functions](#section-three) <br>
# 4. [Data Preprocessing](#section-four)<br>
# 5. [Model Architecture and Training Process](#section-five)<br>
# 6. [Training and Validation Visualizations](#section-six)<br>
# 7. [Model Testing](#section-seven)<br>
# 8. [Conclusion](#section-eight)<br>

# %% [markdown]
# <a id="section-one"></a>
# ## Importing Libraries and Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import cv2
import json
import os
import matplotlib.pyplot as plt
import random
import seaborn as sns
from keras.models import Sequential
from keras import optimizers
from keras import backend as K
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
directory = "/content/drive/MyDrive/Face Mask Detection/archive/Medical mask/Medical mask/Medical Mask/annotations"
image_directory = "/content/drive/MyDrive/Face Mask Detection/archive/Medical mask/Medical mask/Medical Mask/images"
df = pd.read_csv("/content/drive/MyDrive/Face Mask Detection/archive/train.csv")
df_test = pd.read_csv("/content/drive/MyDrive/Face Mask Detection/archive/submission.csv")

# %% [markdown]
# <a id="section-two"></a>
# ## What is SSD?
# SSD is **Single Shot Multibox Detector**. It is a technique that is used to detect objects in images using a single deep neural network. Basically its used for object detection in an image. By using a **base architecture of VGG-16 Architecture**, SSD is able to out perform other object detectors like YOLO and Faster R-CNN in both speed and accuracy. The architecture of SSD is given in the figure below. Training a SSD model from scratch will require a lot of data, so here I have imported pretrained weights **(Caffe Face Detector Model)** using OpenCV.

# %% [markdown]
# ![SSD Architecture](https://www.researchgate.net/profile/Adam_Nowosielski/publication/332948824/figure/fig5/AS:767146284036100@1559913335810/The-model-of-Single-Shot-MultiBox-Detector-SSD-25.ppm)

# %%
cvNet = cv2.dnn.readNetFromCaffe('/content/drive/MyDrive/Face Mask Detection/caffe-face-detector-opencv-pretrained-model/architecture.txt','/content/drive/MyDrive/Face Mask Detection/caffe-face-detector-opencv-pretrained-model/weights.caffemodel')

# %% [markdown]
# <a id="section-three"></a>
# ## Functions
# 1. JSON Function fetches the json file that has the data of bounding box in the training dataset.
# 2. Gamma correction, or often simply gamma, is a nonlinear operation used to encode and decode luminance or tristimulus values in video or still image systems. In simple terms it is used to instill some light in the image. If gamma < 1, image will shift towards darker end of the spectrum and when gamma > 1, there will be more light in the image.

# %%
def getJSON(filePathandName):
    with open(filePathandName,'r') as f:
        return json.load(f)

# %%
def adjust_gamma(image, gamma=1.0):
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255 for i in np.arange(0, 256)])
    return cv2.LUT(image.astype(np.uint8), table.astype(np.uint8))

# %% [markdown]
# <a id="section-four"></a>
# ## Data Preprocessing

# %% [markdown]
# Lets look at the JSON data given for training:
# * The Annotations field contains the data of all the faces present in a particular image.
# * There are various classnames but the true classnames are **face_with_mask** and **face_no_mask**.

# %%
jsonfiles= []
for i in os.listdir(directory):
    jsonfiles.append(getJSON(os.path.join(directory,i)))
jsonfiles[0]
# Out:
# {'Annotations': [{'Attributes': {},
#    'BoundingBox': [96, 0, 430, 432],
#    'Confidence': 1,
#    'ID': 964820035886422400,
#    'classname': 'face_with_mask',
#    'isProtected': False},
#   {'Attributes': {},
#    'BoundingBox': [119, 219, 411, 430],
#    'Confidence': 1,
#    'ID': 571368820964801024,
#    'classname': 'mask_surgical',
#    'isProtected': False},
#   {'Attributes': {},
#    'BoundingBox': [77, 49, 480, 500],
#    'Confidence': 1,
#    'ID': 131405119765588880,
#    'classname': 'face_shield',
#    'isProtected': False}],
#  'FileName': '5317.jpg',
#  'NumOfAnno': 3}

# %%
df = pd.read_csv("/content/drive/MyDrive/Face Mask Detection/archive/train.csv")
df.head()
# Out:
#        name   x1   x2   y1   y2       classname
# 0  2756.png   69  126  294  392  face_with_mask
# 1  2756.png  505   10  723  283  face_with_mask
# 2  2756.png   75  252  264  390   mask_colorful
# 3  2756.png  521  136  711  277   mask_colorful
# 4  6098.jpg  360   85  728  653    face_no_mask

# %% [markdown]
# * By using the mask label and non_mask label, the bounding box data from json files is extracted.
# * The faces from any particular image are extracted and stored in the data list along with its label for the training process.

# %%
data = []
img_size = 124
mask = ['face_with_mask']
non_mask = ["face_no_mask"]
labels={'mask':0,'without mask':1}
for i in df["name"].unique():
    f = i+".json"
    for j in getJSON(os.path.join(directory,f)).get("Annotations"):
        if j["classname"] in mask:
            x,y,w,h = j["BoundingBox"]
            img = cv2.imread(os.path.join(image_directory,i),1)
            img = img[y:h,x:w]
            img = cv2.resize(img,(img_size,img_size))
            data.append([img,labels["mask"]])
        if j["classname"] in non_mask:
            x,y,w,h = j["BoundingBox"]
            img = cv2.imread(os.path.join(image_directory,i),1)
            img = img[y:h,x:w]
            img = cv2.resize(img,(img_size,img_size))    
            data.append([img,labels["without mask"]])
random.shuffle(data)

# %%
len(data)
# Out:
# 5749

# %% [markdown]
# * The visualization below tells us that the **Number of Mask images > Number of Non-Mask images**, so this is an imbalanced dataset. But since we are using a SSD pretrained model, which is trained to detect non-mask faces, this imbalance would not matter a lot.

# %%
p = []
for face in data:
    if(face[1] == 0):
        p.append("Mask")
    else:
        p.append("No Mask")
sns.countplot(p)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X = []
Y = []
for features,label in data:
    X.append(features)
    Y.append(label)

# %%
X[0].shape
# Out:
# (124, 124, 3)

# %%
X = np.array(X)/255.0
X = X.reshape(-1,124,124,3)
Y = np.array(Y)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
Y.shape
# Out:
# (5749,)

# %% [markdown]
# <a id="section-five"></a>
# ## Model Architecture and Training Process

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding = "same", activation='relu', input_shape=(124,124,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 124, 124, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                1254450
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 1,347,749
# Trainable params: 1,347,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam' ,metrics=['accuracy'])

# %%
xtrain,xval,ytrain,yval=train_test_split(X, Y,train_size=0.8,random_state=0)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False,  
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False,    
        rotation_range=15,    
        width_shift_range=0.1,
        height_shift_range=0.1,  
        horizontal_flip=True,  
        vertical_flip=False)
datagen.fit(xtrain)

# %%
history = model.fit(datagen.flow(xtrain, ytrain, batch_size=32),
                    steps_per_epoch=xtrain.shape[0]//32,
                    epochs=100,
                    verbose=1,
                    validation_data=(xval, yval))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 143/143 [==============================] - 41s 114ms/step - loss: 0.4847 - accuracy: 0.7657 - val_loss: 0.2356 - val_accuracy: 0.9122
# Epoch 2/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.2813 - accuracy: 0.8845 - val_loss: 0.2042 - val_accuracy: 0.9217
# Epoch 3/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2522 - accuracy: 0.8970 - val_loss: 0.2234 - val_accuracy: 0.9087
# Epoch 4/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.2517 - accuracy: 0.9037 - val_loss: 0.1987 - val_accuracy: 0.9209
# Epoch 5/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2433 - accuracy: 0.9066 - val_loss: 0.2022 - val_accuracy: 0.9252
# Epoch 6/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2492 - accuracy: 0.8964 - val_loss: 0.2048 - val_accuracy: 0.9174
# Epoch 7/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2159 - accuracy: 0.9152 - val_loss: 0.1795 - val_accuracy: 0.9261
# Epoch 8/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.2296 - accuracy: 0.9129 - val_loss: 0.1896 - val_accuracy: 0.9322
# Epoch 9/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.2129 - accuracy: 0.9128 - val_loss: 0.2159 - val_accuracy: 0.9148
# Epoch 10/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2289 - accuracy: 0.9064 - val_loss: 0.1653 - val_accuracy: 0.9435
# Epoch 11/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2025 - accuracy: 0.9215 - val_loss: 0.2079 - val_accuracy: 0.9261
# Epoch 12/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2242 - accuracy: 0.9121 - val_loss: 0.2138 - val_accuracy: 0.9357
# Epoch 13/100
# 143/143 [==============================] - 15s 106ms/step - loss: 0.1933 - accuracy: 0.9260 - val_loss: 0.2036 - val_accuracy: 0.9270
# Epoch 14/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1734 - accuracy: 0.9344 - val_loss: 0.1691 - val_accuracy: 0.9348
# Epoch 15/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.2007 - accuracy: 0.9279 - val_loss: 0.1488 - val_accuracy: 0.9513
# Epoch 16/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1611 - accuracy: 0.9335 - val_loss: 0.1601 - val_accuracy: 0.9391
# Epoch 17/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1843 - accuracy: 0.9307 - val_loss: 0.1529 - val_accuracy: 0.9426
# Epoch 18/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1673 - accuracy: 0.9376 - val_loss: 0.1626 - val_accuracy: 0.9417
# Epoch 19/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1762 - accuracy: 0.9292 - val_loss: 0.1591 - val_accuracy: 0.9417
# Epoch 20/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1819 - accuracy: 0.9347 - val_loss: 0.1591 - val_accuracy: 0.9391
# Epoch 21/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1623 - accuracy: 0.9430 - val_loss: 0.1749 - val_accuracy: 0.9391
# Epoch 22/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1655 - accuracy: 0.9355 - val_loss: 0.1843 - val_accuracy: 0.9383
# Epoch 23/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1862 - accuracy: 0.9297 - val_loss: 0.1678 - val_accuracy: 0.9391
# Epoch 24/100
# 143/143 [==============================] - 15s 109ms/step - loss: 0.1718 - accuracy: 0.9344 - val_loss: 0.2309 - val_accuracy: 0.9122
# Epoch 25/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1446 - accuracy: 0.9408 - val_loss: 0.1330 - val_accuracy: 0.9557
# Epoch 26/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1574 - accuracy: 0.9443 - val_loss: 0.1572 - val_accuracy: 0.9435
# Epoch 27/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1368 - accuracy: 0.9432 - val_loss: 0.1475 - val_accuracy: 0.9487
# Epoch 28/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1441 - accuracy: 0.9420 - val_loss: 0.1355 - val_accuracy: 0.9504
# Epoch 29/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1378 - accuracy: 0.9469 - val_loss: 0.1394 - val_accuracy: 0.9565
# Epoch 30/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1364 - accuracy: 0.9497 - val_loss: 0.1427 - val_accuracy: 0.9565
# Epoch 31/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1331 - accuracy: 0.9480 - val_loss: 0.1375 - val_accuracy: 0.9583
# Epoch 32/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1271 - accuracy: 0.9534 - val_loss: 0.1467 - val_accuracy: 0.9513
# Epoch 33/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1362 - accuracy: 0.9511 - val_loss: 0.1702 - val_accuracy: 0.9417
# Epoch 34/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1251 - accuracy: 0.9533 - val_loss: 0.1355 - val_accuracy: 0.9530
# Epoch 35/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1224 - accuracy: 0.9569 - val_loss: 0.1464 - val_accuracy: 0.9504
# Epoch 36/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1243 - accuracy: 0.9539 - val_loss: 0.1369 - val_accuracy: 0.9522
# Epoch 37/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1330 - accuracy: 0.9504 - val_loss: 0.1286 - val_accuracy: 0.9591
# Epoch 38/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1263 - accuracy: 0.9500 - val_loss: 0.1242 - val_accuracy: 0.9574
# Epoch 39/100
# 143/143 [==============================] - 16s 108ms/step - loss: 0.1283 - accuracy: 0.9513 - val_loss: 0.1533 - val_accuracy: 0.9530
# Epoch 40/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1428 - accuracy: 0.9468 - val_loss: 0.1632 - val_accuracy: 0.9470
# Epoch 41/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1248 - accuracy: 0.9555 - val_loss: 0.1484 - val_accuracy: 0.9548
# Epoch 42/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1201 - accuracy: 0.9574 - val_loss: 0.1480 - val_accuracy: 0.9504
# Epoch 43/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1451 - accuracy: 0.9516 - val_loss: 0.1342 - val_accuracy: 0.9600
# Epoch 44/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1312 - accuracy: 0.9485 - val_loss: 0.1397 - val_accuracy: 0.9609
# Epoch 45/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1195 - accuracy: 0.9545 - val_loss: 0.1179 - val_accuracy: 0.9661
# Epoch 46/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1103 - accuracy: 0.9629 - val_loss: 0.1242 - val_accuracy: 0.9600
# Epoch 47/100
# 143/143 [==============================] - 16s 108ms/step - loss: 0.1266 - accuracy: 0.9576 - val_loss: 0.1438 - val_accuracy: 0.9609
# Epoch 48/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1209 - accuracy: 0.9588 - val_loss: 0.1247 - val_accuracy: 0.9609
# Epoch 49/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1168 - accuracy: 0.9559 - val_loss: 0.1217 - val_accuracy: 0.9609
# Epoch 50/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1186 - accuracy: 0.9545 - val_loss: 0.1241 - val_accuracy: 0.9609
# Epoch 51/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.1159 - accuracy: 0.9593 - val_loss: 0.1287 - val_accuracy: 0.9609
# Epoch 52/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1007 - accuracy: 0.9589 - val_loss: 0.1336 - val_accuracy: 0.9635
# Epoch 53/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1157 - accuracy: 0.9555 - val_loss: 0.1201 - val_accuracy: 0.9635
# Epoch 54/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1096 - accuracy: 0.9591 - val_loss: 0.1159 - val_accuracy: 0.9652
# Epoch 55/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1063 - accuracy: 0.9615 - val_loss: 0.1313 - val_accuracy: 0.9670
# Epoch 56/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0928 - accuracy: 0.9654 - val_loss: 0.1331 - val_accuracy: 0.9548
# Epoch 57/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.1048 - accuracy: 0.9575 - val_loss: 0.1289 - val_accuracy: 0.9574
# Epoch 58/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1108 - accuracy: 0.9634 - val_loss: 0.1230 - val_accuracy: 0.9617
# Epoch 59/100
# 143/143 [==============================] - 16s 108ms/step - loss: 0.1001 - accuracy: 0.9622 - val_loss: 0.1543 - val_accuracy: 0.9600
# Epoch 60/100
# 143/143 [==============================] - 16s 108ms/step - loss: 0.1086 - accuracy: 0.9593 - val_loss: 0.1381 - val_accuracy: 0.9557
# Epoch 61/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0905 - accuracy: 0.9711 - val_loss: 0.1256 - val_accuracy: 0.9678
# Epoch 62/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0995 - accuracy: 0.9633 - val_loss: 0.1195 - val_accuracy: 0.9661
# Epoch 63/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1252 - accuracy: 0.9535 - val_loss: 0.1263 - val_accuracy: 0.9635
# Epoch 64/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0899 - accuracy: 0.9658 - val_loss: 0.1151 - val_accuracy: 0.9687
# Epoch 65/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1019 - accuracy: 0.9627 - val_loss: 0.1271 - val_accuracy: 0.9626
# Epoch 66/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1008 - accuracy: 0.9628 - val_loss: 0.1359 - val_accuracy: 0.9635
# Epoch 67/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.0957 - accuracy: 0.9653 - val_loss: 0.1268 - val_accuracy: 0.9643
# Epoch 68/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.0872 - accuracy: 0.9650 - val_loss: 0.1268 - val_accuracy: 0.9626
# Epoch 69/100
# 143/143 [==============================] - 15s 107ms/step - loss: 0.0893 - accuracy: 0.9680 - val_loss: 0.1302 - val_accuracy: 0.9713
# Epoch 70/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.1039 - accuracy: 0.9650 - val_loss: 0.1572 - val_accuracy: 0.9565
# Epoch 71/100
# 143/143 [==============================] - 16s 108ms/step - loss: 0.1167 - accuracy: 0.9647 - val_loss: 0.1289 - val_accuracy: 0.9661
# Epoch 72/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0928 - accuracy: 0.9613 - val_loss: 0.1158 - val_accuracy: 0.9687
# Epoch 73/100
# 143/143 [==============================] - 15s 108ms/step - loss: 0.0859 - accuracy: 0.9699 - val_loss: 0.1285 - val_accuracy: 0.9652
# Epoch 74/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0972 - accuracy: 0.9623 - val_loss: 0.1400 - val_accuracy: 0.9609
# Epoch 75/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0937 - accuracy: 0.9637 - val_loss: 0.1242 - val_accuracy: 0.9704
# Epoch 76/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0912 - accuracy: 0.9661 - val_loss: 0.1171 - val_accuracy: 0.9704
# Epoch 77/100
# 143/143 [==============================] - 16s 111ms/step - loss: 0.0820 - accuracy: 0.9694 - val_loss: 0.1597 - val_accuracy: 0.9609
# Epoch 78/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1153 - accuracy: 0.9616 - val_loss: 0.1196 - val_accuracy: 0.9643
# Epoch 79/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0976 - accuracy: 0.9654 - val_loss: 0.1298 - val_accuracy: 0.9635
# Epoch 80/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0785 - accuracy: 0.9675 - val_loss: 0.1242 - val_accuracy: 0.9643
# Epoch 81/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0973 - accuracy: 0.9670 - val_loss: 0.1185 - val_accuracy: 0.9678
# Epoch 82/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0963 - accuracy: 0.9648 - val_loss: 0.1207 - val_accuracy: 0.9626
# Epoch 83/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.1032 - accuracy: 0.9647 - val_loss: 0.1151 - val_accuracy: 0.9670
# Epoch 84/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0948 - accuracy: 0.9595 - val_loss: 0.1145 - val_accuracy: 0.9687
# Epoch 85/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0893 - accuracy: 0.9656 - val_loss: 0.1171 - val_accuracy: 0.9626
# Epoch 86/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0955 - accuracy: 0.9622 - val_loss: 0.1109 - val_accuracy: 0.9704
# Epoch 87/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0788 - accuracy: 0.9729 - val_loss: 0.1264 - val_accuracy: 0.9687
# Epoch 88/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0856 - accuracy: 0.9692 - val_loss: 0.1250 - val_accuracy: 0.9591
# Epoch 89/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0801 - accuracy: 0.9711 - val_loss: 0.1476 - val_accuracy: 0.9600
# Epoch 90/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0830 - accuracy: 0.9702 - val_loss: 0.1218 - val_accuracy: 0.9722
# Epoch 91/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0846 - accuracy: 0.9672 - val_loss: 0.1208 - val_accuracy: 0.9661
# Epoch 92/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0792 - accuracy: 0.9695 - val_loss: 0.1238 - val_accuracy: 0.9635
# Epoch 93/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0861 - accuracy: 0.9674 - val_loss: 0.1161 - val_accuracy: 0.9670
# Epoch 94/100
# 143/143 [==============================] - 16s 110ms/step - loss: 0.0719 - accuracy: 0.9693 - val_loss: 0.1135 - val_accuracy: 0.9661
# Epoch 95/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0754 - accuracy: 0.9732 - val_loss: 0.1210 - val_accuracy: 0.9696
# Epoch 96/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0773 - accuracy: 0.9703 - val_loss: 0.1202 - val_accuracy: 0.9722
# Epoch 97/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0828 - accuracy: 0.9685 - val_loss: 0.1187 - val_accuracy: 0.9730
# Epoch 98/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0924 - accuracy: 0.9682 - val_loss: 0.1495 - val_accuracy: 0.9591
# Epoch 99/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0927 - accuracy: 0.9690 - val_loss: 0.1130 - val_accuracy: 0.9670
# Epoch 100/100
# 143/143 [==============================] - 16s 109ms/step - loss: 0.0791 - accuracy: 0.9686 - val_loss: 0.1177 - val_accuracy: 0.9687

# %% [markdown]
# <a id="section-six"></a>
# ## Training and Validation Visualizations

# %%
plt.plot(history.history['accuracy'],'g')
plt.plot(history.history['val_accuracy'],'b')
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'],'g')
plt.plot(history.history['val_loss'],'b')
plt.title('Training Loss vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# <a id="section-seven"></a>
# ## Model Testing

# %% [markdown]
# The test dataset has 1698 images and to evaluate the model I have taken a handful of images from this dataset as there are no labels for faces in the dataset.

# %%
print(len(df_test["name"]),len(df_test["name"].unique()))
# Out:
# 8142 1698

# %%
df_test['name']
# Out:
# 0       1800.jpg
# 1       1800.jpg
# 2       1800.jpg
# 3       1799.jpg
# 4       1799.jpg
#           ...
# 8137    0003.jpg
# 8138    0002.png
# 8139    0001.jpg
# 8140    0001.jpg
# 8141    0001.jpg
# Name: name, Length: 8142, dtype: object

# %%
test_images = ['1114.png','1797.jpg', '0072.jpg','1796.jpg','0004.jpg','1374.jpg']

# %% [markdown]
# * Gamma Correction for making the image appear in more light.**(Gamma = 2)**
# * blobFromImage creates 4-dimensional blob from image. Optionally resizes and crops image from center, subtract mean values, scales values by scalefactor, swap Blue and Red channels. [Refer OpenCV documentation]
# * The blob is passed through the SSD network and detections are made with some confidence score.
# * Define a threshold confidence score, above which the detection will be considered as a candidate of being a face. (In this case **confidence threshold = 0.2**)
# * All the detections that qualify the confidence score are then passed to the architecture for classification into mask or non-mask image.

# %%
gamma = 2.0
fig = plt.figure(figsize = (14,14))
rows = 3
cols = 2
axes = []
assign = {'0':'Mask','1':"No Mask"}
for j,im in enumerate(test_images):
    image =  cv2.imread(os.path.join(image_directory,im),1)
    image =  adjust_gamma(image, gamma=gamma)
    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(image, (300,300)), 1.0, (300, 300), (104.0, 177.0, 123.0))
    cvNet.setInput(blob)
    detections = cvNet.forward()
    for i in range(0, detections.shape[2]):
        try:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            frame = image[startY:endY, startX:endX]
            confidence = detections[0, 0, i, 2]
            if confidence > 0.2:
                im = cv2.resize(frame,(img_size,img_size))
                im = np.array(im)/255.0
                im = im.reshape(1,124,124,3)
                result = model.predict(im)
                if result>0.5:
                    label_Y = 1
                else:
                    label_Y = 0
                cv2.rectangle(image, (startX, startY), (endX, endY), (0, 0, 255), 2)
                cv2.putText(image,assign[str(label_Y)] , (startX, startY-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (36,255,12), 2)
        
        except:pass
    axes.append(fig.add_subplot(rows, cols, j+1))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# <a id="section-eight"></a>
# ## Conclusion
# By analyzing the results it can be observed that the whole system works well for faces that have spatial dominance i.e. in image at (1,1), (1,2) and (2,1) but fails partially in case of (2,1) because it didnot detect the masked face of Mona Lisa. In (3,2) it fails to detect the third and fourth lady because their faces are small, blurrd, partially visible are small and occupy less space in the overall image. **To get better results, different image preprocessing techniques can be used, or confidence threshold can be kept lower, or one can try different blob size.**
